# %% [markdown]
# # Module Big Data
#
# Contact details:
#
# Jan Buć
#
# jan_buc@epam.com
#
#
#
#
#
# Duration: 2x1,5h.
#
#
#
# Max score: 5 points for report.
#
#
#
# Conditions for completion: attendance, source code and report from exercise being sent to Github.
#
#
#
# Introductory materials:
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/index.html#user-guide
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.MultiIndex.html
# https://en.wikipedia.org/wiki/Extract,_transform,_load
#
#
#
# Required environment:
#
# - VS Code as recomended IDE
# - Installed Jupyter plugin in VS Code
# - Python 3.8
# - Pip for Python 3.8

# %% [markdown]
# # Goal of exercise

# %% [markdown]
# Walkthrough some basic Pandas operation. All code is avaliable and ready to use. There are two common parts with tasks for which code will be written during classes.

# %% [markdown]
# # Report

# %% [markdown]
# File report.ipynb needs to be edited contains all needed informations and send back as report from laboratory.
#
# For report 5 points will be distributed as:
# - 3 points for report send to github after classes (considered as attendance)
# - 1 point common part covered
# - Teoretical introduction for followed topicks (up to 4 sentences will be sufficient)
#      -  What is pandas and it is for
#      -  Vectorized operations
#      -  Differences between native python list and pandas series

# %% [markdown]
# # Environment preparation

# %% [markdown]
# Clone your individual repository with exercise
# > git clone <repo_name>

# %% [markdown]
# Create virtual environment in VS Code terminal
# > python3 -m venv venv

# %% [markdown]
# Install needed dependencies
# > pip install ipykernel
# <br>
# > pip install pandas

# %% [markdown]
# # Introduction

# %%
import pandas as pd

# %% [markdown]
# Data loading nad basic dataframe information

# %%
data = pd.read_csv("sales_records.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          1000 non-null   object
#  1   Country         1000 non-null   object
#  2   Item Type       1000 non-null   object
#  3   Sales Channel   1000 non-null   object
#  4   Order Priority  1000 non-null   object
#  5   Order Date      1000 non-null   object
#  6   Order ID        1000 non-null   int64
#  7   Ship Date       1000 non-null   object
#  8   Units Sold      1000 non-null   int64
#  9   Unit Price      1000 non-null   float64
#  10  Unit Cost       1000 non-null   float64
#  11  Total Revenue   1000 non-null   float64
#  12  Total Cost      1000 non-null   float64
#  13  Total Profit    1000 non-null   float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 109.5+ KB

# %%
data.shape
# Out:
# (1000, 14)

# %%
data.head()
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1              M   11/7/2011  185941302   12/8/2011        3018      154.06
# 2              C  10/31/2016  246222341   12/9/2016        1517      255.28
# 3              C   4/10/2010  161442649   5/12/2010        3322      205.70
# 4              H   8/16/2011  645713555   8/31/2011        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     263.33     3692591.20  2224085.18    1468506.02
# ...

# %%
type(data.Country), type(data), type(data.Country.values)
# Out:
# (pandas.core.series.Series, pandas.core.frame.DataFrame, numpy.ndarray)

# %%
data.iloc[:,1].head(), data.Country.head(), data['Country'].head()
# Out:
# (0     Libya
#  1    Canada
#  2     Libya
#  3     Japan
#  4      Chad
#  Name: Country, dtype: object,
#  0     Libya
#  1    Canada
#  2     Libya
#  3     Japan
#  4      Chad
#  Name: Country, dtype: object,
#  0     Libya
#  1    Canada
#  2     Libya
#  3     Japan
#  4      Chad
#  Name: Country, dtype: object)

# %%
data['Item Type'].value_counts()
# Out:
# Beverages          101
# Vegetables          97
# Office Supplies     89
# Baby Food           87
# Personal Care       87
# Snacks              82
# Cereal              79
# Clothes             78
# Meat                78
# Household           77
# Cosmetics           75
# Fruits              70
# Name: Item Type, dtype: int64

# %% [markdown]
# Boolean indexing, masks

# %% [markdown]
# AND &
# <br>
# OR |
# <br>
# NOT ~

# %%
m_mask = data['Order Priority'] == 'M'

# %%
m_mask.head()
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# Name: Order Priority, dtype: bool

# %%
m_filtered_data = data[m_mask]

# %%
m_filtered_data.head()
# Out:
#                           Region     Country   Item Type Sales Channel  \
# 0   Middle East and North Africa       Libya   Cosmetics       Offline
# 1                  North America      Canada  Vegetables        Online
# 7                         Europe  Montenegro     Clothes       Offline
# 10            Sub-Saharan Africa        Togo     Clothes        Online
# 11                        Europe  Montenegro      Snacks       Offline
#
#    Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0               M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1               M   11/7/2011  185941302   12/8/2011        3018      154.06
# 7               M   5/17/2012  208630645   6/28/2012        7299      109.28
# 10              M  12/29/2015  451010930   1/19/2016        3012      109.28
# 11              M   2/27/2010  220003211   3/18/2010        2694      152.58
#
#     Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
snack_mask = data['Item Type'] == 'Snacks'
m_snack_mask = m_mask & snack_mask
m_snack_filtered_data = data[m_snack_mask]

# %%
m_snack_filtered_data.head()
# Out:
#                  Region     Country Item Type Sales Channel Order Priority  \
# 11               Europe  Montenegro    Snacks       Offline              M
# 55                 Asia    Malaysia    Snacks       Offline              M
# 84   Sub-Saharan Africa      Rwanda    Snacks        Online              M
# 120              Europe      Sweden    Snacks        Online              M
# 121  Sub-Saharan Africa       Gabon    Snacks       Offline              M
#
#     Order Date   Order ID  Ship Date  Units Sold  Unit Price  Unit Cost  \
# 11   2/27/2010  220003211  3/18/2010        2694      152.58      97.44
# 55   10/6/2012  175033080  11/5/2012        5033      152.58      97.44
# 84    3/6/2017  866792809  3/18/2017        2109      152.58      97.44
# 120  4/12/2011  742443025  4/15/2011        4245      152.58      97.44
# 121  10/3/2010  164569461  10/5/2010        8615      152.58      97.44
#
#      Total Revenue  Total Cost  Total Profit
# ...

# %% [markdown]
# String columns handling

# %% [markdown]
# Series.str.contains()
# <br>
# Series.str.startswith()
# <br>
# Series.str.isnumeric()

# %%
africa_mask = data['Region'].str.contains('Africa')
africa_data = data[africa_mask]

# %%
africa_data.head()
# Out:
#                           Region  Country  Item Type Sales Channel  \
# 0   Middle East and North Africa    Libya  Cosmetics       Offline
# 2   Middle East and North Africa    Libya  Baby Food       Offline
# 4             Sub-Saharan Africa     Chad     Fruits       Offline
# 6             Sub-Saharan Africa  Eritrea     Cereal        Online
# 10            Sub-Saharan Africa     Togo    Clothes        Online
#
#    Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0               M  10/18/2014  686800706  10/31/2014        8446      437.20
# 2               C  10/31/2016  246222341   12/9/2016        1517      255.28
# 4               H   8/16/2011  645713555   8/31/2011        9845        9.33
# 6               H    3/4/2015  679414975   4/17/2015        2844      205.70
# 10              M  12/29/2015  451010930   1/19/2016        3012      109.28
#
#     Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %% [markdown]
# Some of basic data conversion

# %%
data[['Ship Date', 'Order Date']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Ship Date   1000 non-null   object
#  1   Order Date  1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
data['Ship Date']= pd.to_datetime(data['Ship Date'])
data['Order Date']= pd.to_datetime(data['Order Date'])

# %%
data[['Ship Date', 'Order Date']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Ship Date   1000 non-null   datetime64[ns]
#  1   Order Date  1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](2)
# memory usage: 15.8 KB

# %% [markdown]
# Show list of 3 countries with lowest units sold:
# - from Africa
# - for selling fruits
# - with C priority
# - between 2013 and 2018 order date

# %%
africa_mask = data['Region'].str.contains('Africa')
m_mask = data['Order Priority'] == 'M'
fruits_mask = data['Item Type'] == 'Fruits'
from_2013_mask = pd.Timestamp(2013,1,1) < data['Order Date']
to_2015_mask = pd.Timestamp(2018,1,1) > data['Order Date']

task1_mask = africa_mask & m_mask & fruits_mask & from_2013_mask & to_2015_mask

task1_data = data[task1_mask]

# %%
task1_data.head()
# Out:
#                  Region                           Country Item Type  \
# 268  Sub-Saharan Africa                           Liberia    Fruits
# 348  Sub-Saharan Africa  Democratic Republic of the Congo    Fruits
# 541  Sub-Saharan Africa                        Madagascar    Fruits
# 545  Sub-Saharan Africa                       South Sudan    Fruits
# 764  Sub-Saharan Africa                        Madagascar    Fruits
#
#     Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 268        Online              M 2014-10-08  217140328 2014-10-30        5503
# 348       Offline              M 2013-04-18  243102395 2013-04-18        8256
# 541       Offline              M 2017-07-08  701816356 2017-07-30        1910
# 545        Online              M 2016-01-09  793938434 2016-02-08        2880
# 764        Online              M 2017-07-23  987714517 2017-09-11        5530
#
#      Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
task1_data.sort_values('Units Sold')['Country'][:3].to_list()
# Out:
# ['Madagascar', 'South Sudan', 'Bahrain']

# %% [markdown]
# # Common part I

# %% [markdown]
# For given data perform followed operations.
# <br>
# - choose one Item Type
# - total cost is higher that total profit
# - show top 3 countries with highest units sold

# %%
data = pd.read_csv("sales_records.csv")
data['Ship Date']= pd.to_datetime(data['Ship Date'])
data['Order Date']= pd.to_datetime(data['Order Date'])
data.head()
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# 0              M 2014-10-18  686800706 2014-10-31        8446      437.20
# 1              M 2011-11-07  185941302 2011-12-08        3018      154.06
# 2              C 2016-10-31  246222341 2016-12-09        1517      255.28
# 3              C 2010-04-10  161442649 2010-05-12        3322      205.70
# 4              H 2011-08-16  645713555 2011-08-31        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     263.33     3692591.20  2224085.18    1468506.02
# ...

# %%
# write your code here
df = data[data['Item Type'] == 'Fruits']
dff = df[df['Total Cost'] > df['Total Profit']]
dff.sort_values('Units Sold', ascending=False)['Country'][:3]
# Out:
# 939      Zimbabwe
# 4            Chad
# 549    Cape Verde
# Name: Country, dtype: object

# %% [markdown]
# # Indexes

# %%
data = pd.read_csv("sample2.csv", sep=', ', engine='python')

# %%
data.head()
# Out:
#               Name Team       Position  Height(inches)  Weight(lbs)    Age
# 0    Adam Donachie  BAL        Catcher              74        180.0  22.99
# 1        Paul Bako  BAL        Catcher              74        215.0  34.69
# 2  Ramon Hernandez  BAL        Catcher              72        210.0  30.78
# 3     Kevin Millar  BAL  First Baseman              72        210.0  35.43
# 4      Chris Gomez  BAL  First Baseman              73        188.0  35.71

# %%
data.loc[1]
# Out:
# Name              Paul Bako
# Team                    BAL
# Position            Catcher
# Height(inches)           74
# Weight(lbs)           215.0
# Age                   34.69
# Name: 1, dtype: object

# %%
data.set_index('Name', inplace=True)

# %%
data.head()
# Out:
#                 Team       Position  Height(inches)  Weight(lbs)    Age
# Name
# Adam Donachie    BAL        Catcher              74        180.0  22.99
# Paul Bako        BAL        Catcher              74        215.0  34.69
# Ramon Hernandez  BAL        Catcher              72        210.0  30.78
# Kevin Millar     BAL  First Baseman              72        210.0  35.43
# Chris Gomez      BAL  First Baseman              73        188.0  35.71

# %% [markdown]
# loc - label-based indexed
# <br>
# iloc - integer position based

# %%
data.loc['Paul Bako'], data.iloc[1]
# Out:
# (Team                  BAL
#  Position          Catcher
#  Height(inches)         74
#  Weight(lbs)         215.0
#  Age                 34.69
#  Name: Paul Bako, dtype: object,
#  Team                  BAL
#  Position          Catcher
#  Height(inches)         74
#  Weight(lbs)         215.0
#  Age                 34.69
#  Name: Paul Bako, dtype: object)

# %%
data.loc['Paul Bako', 'Position']
# Out:
# 'Catcher'

# %%
data.iloc[2:5]
# Out:
#                 Team       Position  Height(inches)  Weight(lbs)    Age
# Name
# Ramon Hernandez  BAL        Catcher              72        210.0  30.78
# Kevin Millar     BAL  First Baseman              72        210.0  35.43
# Chris Gomez      BAL  First Baseman              73        188.0  35.71

# %%
data.reset_index(inplace=True)

# %%
data.head()
# Out:
#               Name Team       Position  Height(inches)  Weight(lbs)    Age
# 0    Adam Donachie  BAL        Catcher              74        180.0  22.99
# 1        Paul Bako  BAL        Catcher              74        215.0  34.69
# 2  Ramon Hernandez  BAL        Catcher              72        210.0  30.78
# 3     Kevin Millar  BAL  First Baseman              72        210.0  35.43
# 4      Chris Gomez  BAL  First Baseman              73        188.0  35.71

# %% [markdown]
# # Groupby

# %% [markdown]
# ![Groupby](groupby.jpg)

# %%
import pandas as pd

# %%
data = pd.read_csv("sample2.csv", sep=', ', engine='python')

# %%
data.head()
# Out:
#               Name Team       Position  Height(inches)  Weight(lbs)    Age
# 0    Adam Donachie  BAL        Catcher              74        180.0  22.99
# 1        Paul Bako  BAL        Catcher              74        215.0  34.69
# 2  Ramon Hernandez  BAL        Catcher              72        210.0  30.78
# 3     Kevin Millar  BAL  First Baseman              72        210.0  35.43
# 4      Chris Gomez  BAL  First Baseman              73        188.0  35.71

# %%
data['Position'].value_counts()
# Out:
# Relief Pitcher       315
# Starting Pitcher     221
# Outfielder           194
# Catcher               76
# Second Baseman        58
# First Baseman         55
# Shortstop             52
# Third Baseman         45
# Designated Hitter     18
# Name: Position, dtype: int64

# %%
grouped_data = data.groupby('Position')

# %%
type(grouped_data)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
grouped_data.get_group('Designated Hitter').head()
# Out:
#               Name Team           Position  Height(inches)  Weight(lbs)    Age
# 16     Jay Gibbons  BAL  Designated Hitter              72        197.0  30.00
# 51       Jim Thome  CWS  Designated Hitter              76        244.0  36.51
# 52     Jerry Owens  CWS  Designated Hitter              75        195.0  26.03
# 118    David Ortiz  BOS  Designated Hitter              76        230.0  31.28
# 155  Travis Hafner  CLE  Designated Hitter              75        240.0  29.74

# %%
for group_key, group_table in grouped_data:
    print(group_key, type(group_table))
# Out:
# Catcher <class 'pandas.core.frame.DataFrame'>
# Designated Hitter <class 'pandas.core.frame.DataFrame'>
# First Baseman <class 'pandas.core.frame.DataFrame'>
# Outfielder <class 'pandas.core.frame.DataFrame'>
# Relief Pitcher <class 'pandas.core.frame.DataFrame'>
# Second Baseman <class 'pandas.core.frame.DataFrame'>
# Shortstop <class 'pandas.core.frame.DataFrame'>
# Starting Pitcher <class 'pandas.core.frame.DataFrame'>
# Third Baseman <class 'pandas.core.frame.DataFrame'>

# %%
grouped_data.head(2)
# Out:
#                 Name Team           Position  Height(inches)  Weight(lbs)  \
# 0      Adam Donachie  BAL            Catcher              74        180.0
# 1          Paul Bako  BAL            Catcher              74        215.0
# 3       Kevin Millar  BAL      First Baseman              72        210.0
# 4        Chris Gomez  BAL      First Baseman              73        188.0
# 5      Brian Roberts  BAL     Second Baseman              69        176.0
# 6      Miguel Tejada  BAL          Shortstop              69        209.0
# 7        Melvin Mora  BAL      Third Baseman              71        200.0
# 8        Aubrey Huff  BAL      Third Baseman              76        231.0
# 9         Adam Stern  BAL         Outfielder              71        180.0
# 10   Jeff Fiorentino  BAL         Outfielder              73        188.0
# 16       Jay Gibbons  BAL  Designated Hitter              72        197.0
# 17       Erik Bedard  BAL   Starting Pitcher              73        189.0
# ...

# %%
grouped_data.count()
# Out:
#                    Name  Team  Height(inches)  Weight(lbs)  Age
# Position
# Catcher              76    76              76           76   76
# Designated Hitter    18    18              18           18   18
# First Baseman        55    55              55           55   55
# Outfielder          194   194             194          194  194
# Relief Pitcher      315   315             315          315  315
# Second Baseman       58    58              58           58   58
# Shortstop            52    52              52           52   52
# Starting Pitcher    221   221             221          220  221
# Third Baseman        45    45              45           45   45

# %%
grouped_data.mean()
# Out:
#                    Height(inches)  Weight(lbs)        Age
# Position
# Catcher                 72.723684   204.328947  29.563684
# Designated Hitter       74.222222   220.888889  30.389444
# First Baseman           74.000000   213.109091  29.474727
# Outfielder              73.010309   199.113402  28.953454
# Relief Pitcher          74.374603   203.517460  28.539810
# Second Baseman          71.362069   184.344828  29.026897
# Shortstop               71.903846   182.923077  28.402885
# Starting Pitcher        74.719457   205.163636  28.236109
# Third Baseman           73.044444   200.955556  28.691111

# %%
grouped_data[['Height(inches)', 'Weight(lbs)', 'Age']].agg(['min', 'max', 'mean', 'count'])
# Out:
#                   Height(inches)                      Weight(lbs)         \
#                              min max       mean count         min    max
# Position
# Catcher                       69  76  72.723684    76       170.0  245.0
# Designated Hitter             70  77  74.222222    18       195.0  275.0
# First Baseman                 70  80  74.000000    55       180.0  260.0
# Outfielder                    68  78  73.010309   194       160.0  257.0
# Relief Pitcher                68  83  74.374603   315       150.0  278.0
# Second Baseman                67  75  71.362069    58       160.0  210.0
# Shortstop                     67  75  71.903846    52       150.0  210.0
# Starting Pitcher              69  82  74.719457   221       150.0  290.0
# Third Baseman                 68  77  73.044444    45       155.0  240.0
#
#                                        Age
#                          mean count    min    max       mean count
# Position
# ...

# %%
grouped_data[['Height(inches)', 'Weight(lbs)', 'Age']].agg({
    'Height(inches)': ['min', 'max'], 
    'Weight(lbs)': ['mean'], 
    'Age': ['min', 'max', 'mean', 'count']})
# Out:
#                   Height(inches)     Weight(lbs)    Age                    \
#                              min max        mean    min    max       mean
# Position
# Catcher                       69  76  204.328947  22.34  38.49  29.563684
# Designated Hitter             70  77  220.888889  23.62  38.76  30.389444
# First Baseman                 70  80  213.109091  22.81  48.52  29.474727
# Outfielder                    68  78  199.113402  21.46  42.60  28.953454
# Relief Pitcher                68  83  203.517460  21.78  42.30  28.539810
# Second Baseman                67  75  184.344828  22.61  41.21  29.026897
# Shortstop                     67  75  182.923077  22.39  39.85  28.402885
# Starting Pitcher              69  82  205.163636  20.90  44.28  28.236109
# Third Baseman                 68  77  200.955556  22.42  37.43  28.691111
#
#
#                   count
# Position
# Catcher              76
# Designated Hitter    18
# First Baseman        55
# Outfielder          194
# ...

# %% [markdown]
# # Stack and Unstack

# %%
import pandas as pd

# %%
df_single_level_cols = pd.DataFrame([[0, 1], [2, 3]],
                                    index=['cat', 'dog'],
                                    columns=['weight', 'height'])
df_single_level_cols
# Out:
#      weight  height
# cat       0       1
# dog       2       3

# %%
df_single_level_cols.stack()
# Out:
# cat  weight    0
#      height    1
# dog  weight    2
#      height    3
# dtype: int64

# %%
data = pd.read_csv("sample2.csv", sep=', ', engine='python')

# %%
data.head()
# Out:
#               Name Team       Position  Height(inches)  Weight(lbs)    Age
# 0    Adam Donachie  BAL        Catcher              74        180.0  22.99
# 1        Paul Bako  BAL        Catcher              74        215.0  34.69
# 2  Ramon Hernandez  BAL        Catcher              72        210.0  30.78
# 3     Kevin Millar  BAL  First Baseman              72        210.0  35.43
# 4      Chris Gomez  BAL  First Baseman              73        188.0  35.71

# %%
gb_size_data = data.groupby(['Team', 'Position']).size()
gb_size_data
# Out:
# Team  Position
# ANA   Catcher              3
#       First Baseman        5
#       Outfielder           8
#       Relief Pitcher       8
#       Shortstop            2
#                           ..
# WAS   Relief Pitcher      14
#       Second Baseman       1
#       Shortstop            3
#       Starting Pitcher     6
#       Third Baseman        1
# Length: 253, dtype: int64

# %%
team_players_data = gb_size_data.unstack('Position')
team_players_data
# Out:
# Position  Catcher  Designated Hitter  First Baseman  Outfielder  \
# Team
# ANA           3.0                NaN            5.0         8.0
# ARZ           2.0                NaN            3.0         5.0
# ATL           2.0                NaN            1.0         7.0
# BAL           3.0                1.0            2.0         7.0
# BOS           3.0                1.0            1.0         7.0
# CHC           3.0                NaN            2.0         8.0
# CIN           3.0                NaN            2.0         8.0
# CLE           2.0                1.0            1.0         8.0
# COL           3.0                1.0            1.0         7.0
# CWS           2.0                2.0            1.0         8.0
# DET           2.0                1.0            2.0         6.0
# FLA           2.0                NaN            1.0         7.0
# HOU           3.0                NaN            2.0         5.0
# KC            2.0                1.0            2.0         6.0
# ...

# %%
team_players_data.fillna(.0, inplace=True)
team_players_data
# Out:
# Position  Catcher  Designated Hitter  First Baseman  Outfielder  \
# Team
# ANA           3.0                0.0            5.0         8.0
# ARZ           2.0                0.0            3.0         5.0
# ATL           2.0                0.0            1.0         7.0
# BAL           3.0                1.0            2.0         7.0
# BOS           3.0                1.0            1.0         7.0
# CHC           3.0                0.0            2.0         8.0
# CIN           3.0                0.0            2.0         8.0
# CLE           2.0                1.0            1.0         8.0
# COL           3.0                1.0            1.0         7.0
# CWS           2.0                2.0            1.0         8.0
# DET           2.0                1.0            2.0         6.0
# FLA           2.0                0.0            1.0         7.0
# HOU           3.0                0.0            2.0         5.0
# KC            2.0                1.0            2.0         6.0
# ...

# %% [markdown]
# # Advanced indexing

# %%
team_players_data_stacked = team_players_data.stack()
team_players_data_stacked
# Out:
# Team  Position
# ANA   Catcher               3.0
#       Designated Hitter     0.0
#       First Baseman         5.0
#       Outfielder            8.0
#       Relief Pitcher        8.0
#                            ...
# WAS   Relief Pitcher       14.0
#       Second Baseman        1.0
#       Shortstop             3.0
#       Starting Pitcher      6.0
#       Third Baseman         1.0
# Length: 270, dtype: float64

# %%
team_players_data_stacked_mask = team_players_data_stacked > 10

# %%
team_players_data_stacked_mask
# Out:
# Team  Position
# ANA   Catcher              False
#       Designated Hitter    False
#       First Baseman        False
#       Outfielder           False
#       Relief Pitcher       False
#                            ...
# WAS   Relief Pitcher        True
#       Second Baseman       False
#       Shortstop            False
#       Starting Pitcher     False
#       Third Baseman        False
# Length: 270, dtype: bool

# %%
team_players_data_index = team_players_data_stacked[team_players_data_stacked_mask].index
team_players_data_index
# Out:
# MultiIndex([('ATL',   'Relief Pitcher'),
#             ('BAL',   'Relief Pitcher'),
#             ('BOS',   'Relief Pitcher'),
#             ('CHC', 'Starting Pitcher'),
#             ('CIN',   'Relief Pitcher'),
#             ('CLE',   'Relief Pitcher'),
#             ('DET',   'Relief Pitcher'),
#             ('FLA',   'Relief Pitcher'),
#             ('NYM',   'Relief Pitcher'),
#             ('OAK',   'Relief Pitcher'),
#             ('PHI',   'Relief Pitcher'),
#             ( 'SD',   'Relief Pitcher'),
#             ( 'SF',   'Relief Pitcher'),
#             ('STL',   'Relief Pitcher'),
#             ('TEX',   'Relief Pitcher'),
#             ('TOR',   'Relief Pitcher'),
#             ('WAS',   'Relief Pitcher')],
#            names=['Team', 'Position'])

# %%
data = pd.read_csv("sample2.csv", sep=', ', engine='python')
data.set_index(['Team', 'Position'], append=True, inplace=True)
data.reset_index([0], inplace=True)
data
# Out:
#                      level_0             Name  Height(inches)  Weight(lbs)  \
# Team Position
# BAL  Catcher               0    Adam Donachie              74        180.0
#      Catcher               1        Paul Bako              74        215.0
#      Catcher               2  Ramon Hernandez              72        210.0
#      First Baseman         3     Kevin Millar              72        210.0
#      First Baseman         4      Chris Gomez              73        188.0
# ...                      ...              ...             ...          ...
# STL  Relief Pitcher     1029    Brad Thompson              73        190.0
#      Relief Pitcher     1030    Tyler Johnson              74        180.0
#      Relief Pitcher     1031   Chris Narveson              75        205.0
#      Relief Pitcher     1032    Randy Keisler              75        190.0
#      Relief Pitcher     1033      Josh Kinney              73        195.0
#
#                        Age
# Team Position
# ...

# %%
filtered_data = data.loc[team_players_data_index]
filtered_data
# Out:
#                      level_0             Name  Height(inches)  Weight(lbs)  \
# Team Position
# ATL  Relief Pitcher      507    Phil Stockman              80        240.0
#      Relief Pitcher      508    Macay McBride              71        210.0
#      Relief Pitcher      509      Joey Devine              71        195.0
#      Relief Pitcher      510     Peter Moylan              74        200.0
#      Relief Pitcher      511    Mike Gonzalez              74        205.0
# ...                      ...              ...             ...          ...
# WAS  Relief Pitcher      928        Jon Rauch              83        260.0
#      Relief Pitcher      929  Jerome Williams              75        246.0
#      Relief Pitcher      930       Luis Ayala              74        186.0
#      Relief Pitcher      931      Ryan Wagner              76        210.0
#      Relief Pitcher      932     Chad Cordero              72        198.0
#
#                        Age
# Team Position
# ...

# %%
gb_filtered_data = filtered_data.groupby(['Team', 'Position'], group_keys=False)

# %%
def calc_custom_kpi(df: pd.DataFrame) -> pd.Series:
    return (df['Height(inches)'] * 1 + df['Weight(lbs)'] * 1.5 + df['Age'] * 1) / 3

# %%
custom_kpi_data = gb_filtered_data.apply(calc_custom_kpi)

# %%
custom_kpi_data
# Out:
# Team  Position
# ATL   Relief Pitcher    155.700000
#       Relief Pitcher    136.783333
#       Relief Pitcher    128.983333
#       Relief Pitcher    134.080000
#       Relief Pitcher    136.756667
#                            ...
# WAS   Relief Pitcher    167.140000
#       Relief Pitcher    156.413333
#       Relief Pitcher    127.376667
#       Relief Pitcher    138.543333
#       Relief Pitcher    131.316667
# Length: 202, dtype: float64

# %%
mean_team_kpi_min_10_players = custom_kpi_data.groupby('Team').mean()
mean_team_kpi_min_10_players
# Out:
# Team
# ATL    137.570714
# BAL    131.718788
# BOS    136.463333
# CHC    135.773333
# CIN    140.238485
# CLE    139.048974
# DET    140.001944
# FLA    135.228056
# NYM    131.995385
# OAK    129.859394
# PHI    128.836970
# SD     136.341282
# SF     136.202727
# STL    134.648788
# TEX    136.278182
# TOR    134.778333
# WAS    135.237143
# dtype: float64

# %% [markdown]
# # Add columns and insufficient data handling (simple case)

# %%
data = pd.read_csv("sample2.csv", sep=', ', engine='python')
data = data.assign(team_kpi_data=None)
data
# Out:
#                  Name Team        Position  Height(inches)  Weight(lbs)  \
# 0       Adam Donachie  BAL         Catcher              74        180.0
# 1           Paul Bako  BAL         Catcher              74        215.0
# 2     Ramon Hernandez  BAL         Catcher              72        210.0
# 3        Kevin Millar  BAL   First Baseman              72        210.0
# 4         Chris Gomez  BAL   First Baseman              73        188.0
# ...               ...  ...             ...             ...          ...
# 1029    Brad Thompson  STL  Relief Pitcher              73        190.0
# 1030    Tyler Johnson  STL  Relief Pitcher              74        180.0
# 1031   Chris Narveson  STL  Relief Pitcher              75        205.0
# 1032    Randy Keisler  STL  Relief Pitcher              75        190.0
# 1033      Josh Kinney  STL  Relief Pitcher              73        195.0
#
#         Age team_kpi_data
# 0     22.99          None
# 1     34.69          None
# ...

# %%
data.set_index(['Team'], inplace=True)
data
# Out:
#                  Name        Position  Height(inches)  Weight(lbs)    Age  \
# Team
# BAL     Adam Donachie         Catcher              74        180.0  22.99
# BAL         Paul Bako         Catcher              74        215.0  34.69
# BAL   Ramon Hernandez         Catcher              72        210.0  30.78
# BAL      Kevin Millar   First Baseman              72        210.0  35.43
# BAL       Chris Gomez   First Baseman              73        188.0  35.71
# ...               ...             ...             ...          ...    ...
# STL     Brad Thompson  Relief Pitcher              73        190.0  25.08
# STL     Tyler Johnson  Relief Pitcher              74        180.0  25.73
# STL    Chris Narveson  Relief Pitcher              75        205.0  25.19
# STL     Randy Keisler  Relief Pitcher              75        190.0  31.01
# STL       Josh Kinney  Relief Pitcher              73        195.0  27.92
#
#      team_kpi_data
# Team
# BAL           None
# BAL           None
# ...

# %%
data['team_kpi_data'] = mean_team_kpi_min_10_players
data
# Out:
#                  Name        Position  Height(inches)  Weight(lbs)    Age  \
# Team
# BAL     Adam Donachie         Catcher              74        180.0  22.99
# BAL         Paul Bako         Catcher              74        215.0  34.69
# BAL   Ramon Hernandez         Catcher              72        210.0  30.78
# BAL      Kevin Millar   First Baseman              72        210.0  35.43
# BAL       Chris Gomez   First Baseman              73        188.0  35.71
# ...               ...             ...             ...          ...    ...
# STL     Brad Thompson  Relief Pitcher              73        190.0  25.08
# STL     Tyler Johnson  Relief Pitcher              74        180.0  25.73
# STL    Chris Narveson  Relief Pitcher              75        205.0  25.19
# STL     Randy Keisler  Relief Pitcher              75        190.0  31.01
# STL       Josh Kinney  Relief Pitcher              73        195.0  27.92
#
#       team_kpi_data
# Team
# BAL      131.718788
# BAL      131.718788
# ...

# %%
data['team_kpi_data'].value_counts(dropna=False)
# Out:
# NaN           435
# 131.995385     38
# 129.859394     37
# 140.001944     37
# 137.570714     37
# 135.773333     36
# 140.238485     36
# 136.463333     36
# 135.237143     36
# 128.836970     36
# 131.718788     35
# 136.278182     35
# 139.048974     35
# 134.778333     34
# 136.202727     34
# 136.341282     33
# 135.228056     32
# 134.648788     32
# Name: team_kpi_data, dtype: int64

# %% [markdown]
# # Common part II

# %% [markdown]
# For given data perform followed operations (stack and unstack methods are not needed).
# <br><br>
# - For one choosen item type
# - Grouped by region
# - For regions that have at least 7 coutries
#     - Calculate ratio between total cost and total profit
# - Calculate mean ratio for every region

# %%
data = pd.read_csv("sales_records.csv")
data['Ship Date']= pd.to_datetime(data['Ship Date'])
data['Order Date']= pd.to_datetime(data['Order Date'])
data.head()
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# 0              M 2014-10-18  686800706 2014-10-31        8446      437.20
# 1              M 2011-11-07  185941302 2011-12-08        3018      154.06
# 2              C 2016-10-31  246222341 2016-12-09        1517      255.28
# 3              C 2010-04-10  161442649 2010-05-12        3322      205.70
# 4              H 2011-08-16  645713555 2011-08-31        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     263.33     3692591.20  2224085.18    1468506.02
# ...

# %%
# write your code here

# %%
df = data[data['Item Type'] == 'Fruits']
dfg = df.groupby('Region')
dfgc = dfg.count()
dfgc
# Out:
#                                    Country  Item Type  Sales Channel  \
# Region
# Asia                                     8          8              8
# Australia and Oceania                    5          5              5
# Central America and the Caribbean        6          6              6
# Europe                                  14         14             14
# Middle East and North Africa             7          7              7
# North America                            1          1              1
# Sub-Saharan Africa                      29         29             29
#
#                                    Order Priority  Order Date  Order ID  \
# Region
# Asia                                            8           8         8
# Australia and Oceania                           5           5         5
# Central America and the Caribbean               6           6         6
# Europe                                         14          14        14
# ...

# %%
dfgc7 = dfgc[dfgc['Country'] > 7]
dfgc7
# Out:
#                     Country  Item Type  Sales Channel  Order Priority  \
# Region
# Asia                      8          8              8               8
# Europe                   14         14             14              14
# Sub-Saharan Africa       29         29             29              29
#
#                     Order Date  Order ID  Ship Date  Units Sold  Unit Price  \
# Region
# Asia                         8         8          8           8           8
# Europe                      14        14         14          14          14
# Sub-Saharan Africa          29        29         29          29          29
#
#                     Unit Cost  Total Revenue  Total Cost  Total Profit
# Region
# Asia                        8              8           8             8
# Europe                     14             14          14            14
# Sub-Saharan Africa         29             29          29            29

# %%
fdf = df.set_index('Region').loc[dfgc7.index]
fdf.head()
# Out:
#             Country Item Type Sales Channel Order Priority Order Date  \
# Region
# Asia       Maldives    Fruits       Offline              L 2011-01-08
# Asia          India    Fruits        Online              H 2010-07-29
# Asia    South Korea    Fruits       Offline              L 2010-03-07
# Asia     Kyrgyzstan    Fruits        Online              C 2012-01-14
# Asia       Mongolia    Fruits        Online              M 2013-09-12
#
#          Order ID  Ship Date  Units Sold  Unit Price  Unit Cost  \
# Region
# Asia    714135205 2011-02-06        7332        9.33       6.92
# Asia    658348691 2010-08-22        8862        9.33       6.92
# Asia    769205892 2010-03-17        3972        9.33       6.92
# Asia    402614009 2012-03-02        1287        9.33       6.92
# Asia    171131217 2013-10-08         385        9.33       6.92
#
#         Total Revenue  Total Cost  Total Profit
# Region
# Asia         68407.56    50737.44      17670.12
# ...

# %%
kpi = fdf['Total Cost'] / fdf['Total Profit']
kpi
# Out:
# Region
# Asia                  2.871369
# Asia                  2.871369
# Asia                  2.871369
# Asia                  2.871369
# Asia                  2.871369
# Asia                  2.871369
# Asia                  2.871369
# Asia                  2.871369
# Europe                2.871369
# Europe                2.871369
# Europe                2.871369
# Europe                2.871369
# Europe                2.871369
# Europe                2.871369
# Europe                2.871369
# Europe                2.871369
# Europe                2.871369
# Europe                2.871369
# Europe                2.871369
# Europe                2.871369
# Europe                2.871369
# Europe                2.871369
# Sub-Saharan Africa    2.871369
# Sub-Saharan Africa    2.871369
# Sub-Saharan Africa    2.871369
# Sub-Saharan Africa    2.871369
# Sub-Saharan Africa    2.871369
# Sub-Saharan Africa    2.871369
# Sub-Saharan Africa    2.871369
# Sub-Saharan Africa    2.871369
# ...

# %%
kpi.groupby('Region').mean()
# Out:
# Region
# Asia                  2.871369
# Europe                2.871369
# Sub-Saharan Africa    2.871369
# dtype: float64
